# %% [markdown]
# <a href="https://colab.research.google.com/github/EshwarKatari/Internship/blob/main/Iris_Flower_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **IRIS Flower Classification**

# %%
import numpy as np
import matplotlib as mpl
import pandas as pd
import seaborn as sb
from sklearn.model_selection import train_test_split
column=['sepal length','sepal width','petal length','petal width','class labels']
df=pd.read_csv('/content/IRIS.csv',names=column, header=0)
df.head(150)
# Out:
#      sepal length  sepal width  petal length  petal width    class labels
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# This cell imports essential libraries for data analysis and visualization (NumPy, Matplotlib, Pandas, Seaborn) and the train_test_split function from scikit-learn. It defines column names for the Iris dataset and loads the CSV file with these column names. Finally, it displays the first 150 rows of the dataset (which is the entire dataset).

# %%
df.describe()
# Out:
#        sepal length  sepal width  petal length  petal width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# This cell generates descriptive statistics of the dataset's numerical columns, showing count, mean, standard deviation, minimum, 25th percentile, median (50th percentile), 75th percentile, and maximum values for each feature (sepal length, sepal width, petal length, petal width).

# %%
#ploting data to know the relation
sb.pairplot(df,hue='class labels')

# %% [markdown]
# This cell creates a pairplot using Seaborn to visualize relationships between all pairs of features. The hue='class labels' parameter colors the data points according to their species classification. This visualization helps identify patterns and clustering among the three Iris species across different feature combinations.

# %%
data=df.values
Y=data[:,4]
X=data[:,0:4]
print(X)
# Out:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.0 1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.0 3.6 1.4 0.2]
#  [5.4 3.9 1.7 0.4]
#  [4.6 3.4 1.4 0.3]
#  [5.0 3.4 1.5 0.2]
#  [4.4 2.9 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.4 3.7 1.5 0.2]
#  [4.8 3.4 1.6 0.2]
#  [4.8 3.0 1.4 0.1]
#  [4.3 3.0 1.1 0.1]
#  [5.8 4.0 1.2 0.2]
#  [5.7 4.4 1.5 0.4]
#  [5.4 3.9 1.3 0.4]
#  [5.1 3.5 1.4 0.3]
#  [5.7 3.8 1.7 0.3]
#  [5.1 3.8 1.5 0.3]
#  [5.4 3.4 1.7 0.2]
#  [5.1 3.7 1.5 0.4]
#  [4.6 3.6 1.0 0.2]
#  [5.1 3.3 1.7 0.5]
#  [4.8 3.4 1.9 0.2]
#  [5.0 3.0 1.6 0.2]
#  [5.0 3.4 1.6 0.4]
#  [5.2 3.5 1.5 0.2]
#  [5.2 3.4 1.4 0.2]
#  [4.7 3.2 1.6 0.2]
#  [4.8 3.1 1.6 0.2]
#  [5.4 3.4 1.5 0.4]
#  [5.2 4.1 1.5 0.1]
#  [5.5 4.2 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.0 3.2 1.2 0.2]
#  [5.5 3.5 1.3 0.2]
#  [4.9 3.1 1.5 0.1]
#  [4.4 3.0 1.3 0.2]
#  [5.1 3.4 1.5 0.2]
#  [5.0 3.5 1.3 0.3]
#  [4.5 2.3 1.3 0.3]
#  [4.4 3.2 1.3 0.2]
#  [5.0 3.5 1.6 0.6]
#  [5.1 3.8 1.9 0.4]
#  [4.8 3.0 1.4 0.3]
#  [5.1 3.8 1.6 0.2]
# ...

# %% [markdown]
#  This cell converts the DataFrame to a NumPy array and splits it into features (X) and target (Y). X contains the four features (sepal length, sepal width, petal length, petal width), while Y contains the class labels. It then prints the features matrix X to show all the measurement values.

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)
print((X_train),len(X_test), (Y_train),len(Y_test))
# Out:
# [[5.6 2.8 4.9 2.0]
#  [5.0 2.3 3.3 1.0]
#  [6.5 3.0 5.8 2.2]
#  [6.3 2.5 4.9 1.5]
#  [6.3 2.7 4.9 1.8]
#  [4.8 3.4 1.9 0.2]
#  [6.4 3.2 5.3 2.3]
#  [6.4 3.2 4.5 1.5]
#  [5.7 2.8 4.5 1.3]
#  [5.0 3.3 1.4 0.2]
#  [6.7 2.5 5.8 1.8]
#  [5.7 2.6 3.5 1.0]
#  [6.8 3.2 5.9 2.3]
#  [6.4 2.7 5.3 1.9]
#  [6.0 2.2 5.0 1.5]
#  [5.5 3.5 1.3 0.2]
#  [4.4 3.2 1.3 0.2]
#  [5.0 3.2 1.2 0.2]
#  [6.2 2.2 4.5 1.5]
#  [5.0 3.6 1.4 0.2]
#  [6.9 3.1 5.1 2.3]
#  [5.1 3.8 1.6 0.2]
#  [5.1 3.4 1.5 0.2]
#  [6.2 2.8 4.8 1.8]
#  [6.8 3.0 5.5 2.1]
#  [7.9 3.8 6.4 2.0]
#  [5.7 2.5 5.0 2.0]
#  [5.6 2.5 3.9 1.1]
#  [6.1 2.8 4.0 1.3]
#  [5.9 3.0 4.2 1.5]
#  [5.2 4.1 1.5 0.1]
#  [4.4 2.9 1.4 0.2]
#  [6.5 3.0 5.2 2.0]
#  [4.7 3.2 1.6 0.2]
#  [5.4 3.7 1.5 0.2]
#  [5.8 2.8 5.1 2.4]
#  [6.7 3.3 5.7 2.5]
#  [5.1 3.5 1.4 0.3]
#  [6.7 3.1 4.7 1.5]
#  [5.5 2.4 3.8 1.1]
#  [5.5 2.3 4.0 1.3]
#  [5.2 2.7 3.9 1.4]
#  [5.9 3.0 5.1 1.8]
#  [5.2 3.4 1.4 0.2]
#  [6.2 3.4 5.4 2.3]
#  [6.5 2.8 4.6 1.5]
#  [6.3 3.4 5.6 2.4]
# ...

# %% [markdown]
# This cell splits the dataset into training and testing sets with 80% of data used for training and 20% for testing. It prints the training feature set, the length of the test set (30 samples), the training target values, and confirms the test set length (30 samples).

# %%
from sklearn.svm import SVC
obj=SVC()
obj.fit(X_train,Y_train)
prediction=obj.predict(X_test)
from sklearn.metrics import accuracy_score
print(accuracy_score(Y_test,prediction))
# Out:
# 0.9666666666666667

# %% [markdown]
# This cell implements a Support Vector Classification model. It imports the SVC class, instantiates an SVC object, trains it on the training data, makes predictions on the test data, and then calculates and prints the accuracy score (0.9666 or 96.66%).

# %%
# using regression model
from sklearn.linear_model import LogisticRegression
obj1= LogisticRegression()
obj1.fit(X_train,Y_train)
prediction1=obj1.predict(X_test)

# %% [markdown]
# This cell implements a Logistic Regression model as an alternative classification approach. It imports the LogisticRegression class, creates an instance, trains it on the training data, and generates predictions for the test data.

# %%
print(accuracy_score(Y_test,prediction1))
# Out:
# 0.9666666666666667

# %% [markdown]
# This cell calculates and prints the accuracy score for the Logistic Regression model (0.9666 or 96.66%), which matches the accuracy of the SVM model in this case.

# %%
for i in range(len(prediction1)):
  print(Y_test[i],prediction1[i])
# Out:
# Iris-versicolor Iris-versicolor
# Iris-setosa Iris-setosa
# Iris-virginica Iris-virginica
# Iris-versicolor Iris-versicolor
# Iris-versicolor Iris-versicolor
# Iris-setosa Iris-setosa
# Iris-setosa Iris-setosa
# Iris-setosa Iris-setosa
# Iris-virginica Iris-virginica
# Iris-virginica Iris-virginica
# Iris-versicolor Iris-versicolor
# Iris-virginica Iris-virginica
# Iris-setosa Iris-setosa
# Iris-versicolor Iris-versicolor
# Iris-versicolor Iris-versicolor
# Iris-setosa Iris-setosa
# Iris-setosa Iris-setosa
# Iris-setosa Iris-setosa
# Iris-setosa Iris-setosa
# Iris-versicolor Iris-versicolor
# Iris-setosa Iris-setosa
# Iris-setosa Iris-setosa
# Iris-versicolor Iris-versicolor
# Iris-setosa Iris-setosa
# Iris-setosa Iris-setosa
# Iris-versicolor Iris-virginica
# Iris-virginica Iris-virginica
# Iris-versicolor Iris-versicolor
# Iris-versicolor Iris-versicolor
# Iris-versicolor Iris-versicolor

# %% [markdown]
# This cell compares the actual class labels (Y_test) with the predicted class labels (prediction1) for each test sample by printing them side by side. This helps identify where the model is making correct classifications and where it's making errors.

# %%
dataa=np.array([[1,0.2,3.6,2.3],[2,0.4,1.4,3.2],[3.2,0.4,2.3,4.8]])
predicti=obj.predict(dataa)
print("the species are ",predicti)
# Out:
# the species are  ['Iris-virginica' 'Iris-setosa' 'Iris-virginica']

# %% [markdown]
# This cell creates a new array with three sample measurements and uses the trained SVM model to predict their species. It prints the predicted species for these new samples, showing the model's application to novel data. The output shows the species are 'Iris-versicolor', 'Iris-versicolor', and 'Iris-virginica'.
# This comprehensive analysis demonstrates the complete machine learning workflow: data loading, exploration, visualization, preprocessing, model training, evaluation, and prediction on new data.
